# %%
#import the dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
import time
# Set up Splinter
browser = Browser('chrome')

# %%
# define the url to inspect
url = 'https://www.imdb.com/list/ls057886464/'
#visit the browser
browser.visit(url)

# %%
# parse the html
html = browser.html
song_soup = soup(html , 'html.parser')

# %%
# get the main mage content by inspecting the class
title_elem = song_soup.find('div',  class_ = 'lister list detail sub-list')
print(soup.prettify(title_elem))
# Out:
# <div class="lister list detail sub-list">
#  <div class="header filmosearch">
#   <div class="nav">
#    <div class="lister-controls float-right lister-activated" style="display: block;">
#     <div class="lister-control-group">
#      Sort by:
#      <br/>
#      <select class="lister-sort-by" name="sort">
#       <option selected="selected" value="list_order:ascending">
#        List Order
#       </option>
#       <option value="moviemeter:ascending">
#        Popularity
#       </option>
#       <option value="alpha:ascending">
#        Alphabetical
#       </option>
#       <option value="user_rating:descending">
#        IMDb Rating
#       </option>
#       <option value="num_votes:descending">
#        Number of Votes
#       </option>
#       <option value="release_date:descending">
#        Release Date
#       </option>
#       <option value="runtime:descending">
#        Runtime
#       </option>
#       <option value="date_added:descending">
#        Date Added
#       </option>
#      </select>
#      <span class="global-sprite lister-sort-reverse descending" data-sort="list_order:descending" title="Ascending order">
#      </span>
#     </div>
#     <div class="lister-control-group">
#      View:
#      <br/>
#      <span +="" class="global-sprite lister-mode grid" data-mode="grid" ref-marker="ttls_vw_grd" title="Grid view">
#      </span>
#      <span +="" class="global-sprite lister-mode detail active" data-mode="detail" ref-marker="ttls_vm_dtl" title="Detail view">
#      </span>
#      <span +="" class="global-sprite lister-mode simple" data-mode="simple" ref-marker="ttls_vw_smp" title="Compact view">
#      </span>
#     </div>
#    </div>
#    <div class="desc lister-total-num-results">
#     100 titles
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#  </div>
#  <div class="clear">
#  </div>
#  <div class="lister-list">
#   <div class="lister-item mode-detail">
#    <div class="lister-item-image ribbonize" data-tconst="tt0903747" style="position: relative;">
#     <a href="/title/tt0903747/?ref_=ttls_li_i">
#      <img alt="Breaking Bad" class="loadlate" data-tconst="tt0903747" height="209" src="https://m.media-amazon.com/images/M/MV5BYmQ4YWMxYjUtNjZmYi00MDQ1LWFjMjMtNjA5ZDdiYjdiODU5XkEyXkFqcGdeQXVyMTMzNDExODE5._V1_UX140_CR0,0,140,209_AL_.jpg" width="140"/>
#     </a>
#     <div class="wl-ribbon poster touch retina not-inWL" title="Click to add to watchlist">
#     </div>
#    </div>
#    <div class="lister-item-content">
#     <h3 class="lister-item-header">
#      <span class="lister-item-index unbold text-primary">
#       1.
#      </span>
#      <a href="/title/tt0903747/?ref_=ttls_li_tt">
#       Breaking Bad
#      </a>
#      <span class="lister-item-year text-muted unbold">
#       (2008–2013)
#      </span>
#     </h3>
#     <p class="text-muted text-small">
#      <span class="certificate">
#       TV-MA
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="runtime">
#       49 min
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="genre">
#       Crime, Drama, Thriller
#      </span>
#     </p>
#     <div class="ipl-rating-widget">
#      <div class="ipl-rating-star small">
#       <span class="ipl-rating-star__star">
#        <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#         <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#         </path>
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#        </svg>
#       </span>
#       <span class="ipl-rating-star__rating">
#        9.5
#       </span>
#      </div>
#      <div class="ipl-rating-interactive small ipl-rating-interactive--no-rating">
#       <input class="ipl-rating-interactive__state" data-reftag="ur_rt" data-tconst="tt0903747" id="checkbox-tt0903747" type="checkbox"/>
#       <label class="ipl-rating-interactive__star-container" for="checkbox-tt0903747">
#        <div class="ipl-rating-star ipl-rating-interactive__star">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#           <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          Rate
#         </span>
#        </div>
#       </label>
#       <div class="ipl-rating-selector" data-value="0" id="ipl-rating-selector-tt0903747">
#        <div class="ipl-rating-selector__selector ipl-rating-selector__wrapper">
#         <div class="ipl-rating-selector__reset">
#          <a href="#void">
#           <svg class="ipl-icon ipl-cancel-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M12 2C6.47 2 2 6.47 2 12s4.47 10 10 10 10-4.47 10-10S17.53 2 12 2zm5 13.59L15.59 17 12 13.41 8.41 17 7 15.59 10.59 12 7 8.41 8.41 7 12 10.59 15.59 7 17 8.41 13.41 12 17 15.59z">
#            </path>
#            <path d="M0 0h24v24H0z" fill="none">
#            </path>
#           </svg>
#          </a>
#         </div>
#         <span class="ipl-rating-selector__divider">
#         </span>
#         <form action="/ratings/_ajax/title" class="ipl-rating-selector__star-list" method="post">
#          <a class="ipl-rating-selector__star-link" data-value="1" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             1
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="2" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             2
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="3" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             3
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="4" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             4
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="5" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             5
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="6" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             6
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="7" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             7
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="8" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             8
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="9" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             9
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="10" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             10
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <fieldset class="ipl-rating-selector__fieldset">
#           <input name="tconst" type="hidden" value="tt0903747"/>
#           <input name="rating" type="text" value="0"/>
#           <input name="csrfToken" type="hidden" value=""/>
#           <input name="tracking_tag" type="hidden" value="ur_rt"/>
#           <input name="pageType" type="hidden" value="list"/>
#           <input name="subpageType" type="hidden" value="title"/>
#          </fieldset>
#          <noscript>
#           <input class="ipl-rating-selector__rating-submit" type="submit" value="Vote">
#           </input>
#          </noscript>
#         </form>
#         <span class="ipl-rating-selector__rating-value">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-selector__error ipl-rating-selector__wrapper">
#         <span>
#          Error: please try again.
#         </span>
#        </div>
#       </div>
#       <div class="ipl-rating-interactive__loader">
#        <img alt="loading" src="https://m.media-amazon.com/images/G/01/IMDb/spinning-progress.gif"/>
#       </div>
#      </div>
#     </div>
#     <p class="">
#      A chemistry teacher diagnosed with inoperable lung cancer turns to manufacturing and selling methamphetamine with a former student in order to secure his family's future.
#     </p>
#     <p class="text-muted text-small">
#      Stars:
#      <a href="/name/nm0186505/?ref_=ttls_li_st_0">
#       Bryan Cranston
#      </a>
#      ,
#      <a href="/name/nm0666739/?ref_=ttls_li_st_1">
#       Aaron Paul
#      </a>
#      ,
#      <a href="/name/nm0348152/?ref_=ttls_li_st_2">
#       Anna Gunn
#      </a>
#      ,
#      <a href="/name/nm1336827/?ref_=ttls_li_st_3">
#       Betsy Brandt
#      </a>
#     </p>
#     <p class="text-muted text-small">
#      <span class="text-muted">
#       Votes:
#      </span>
#      <span data-value="1968905" name="nv">
#       1,968,905
#      </span>
#     </p>
#     <div class="wtw-option-standalone" data-baseref="wl_li" data-tconst="tt0903747" data-watchtype="minibar">
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#   <div class="lister-item mode-detail">
#    <div class="lister-item-image ribbonize" data-tconst="tt0944947" style="position: relative;">
#     <a href="/title/tt0944947/?ref_=ttls_li_i">
#      <img alt="Game of Thrones" class="loadlate" data-tconst="tt0944947" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BYTRiNDQwYzAtMzVlZS00NTI5LWJjYjUtMzkwNTUzMWMxZTllXkEyXkFqcGdeQXVyNDIzMzcwNjc@._V1_UY209_CR7,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="140"/>
#     </a>
#     <div class="wl-ribbon poster touch retina not-inWL" title="Click to add to watchlist">
#     </div>
#    </div>
#    <div class="lister-item-content">
#     <h3 class="lister-item-header">
#      <span class="lister-item-index unbold text-primary">
#       2.
#      </span>
#      <a href="/title/tt0944947/?ref_=ttls_li_tt">
#       Game of Thrones
#      </a>
#      <span class="lister-item-year text-muted unbold">
#       (2011–2019)
#      </span>
#     </h3>
#     <p class="text-muted text-small">
#      <span class="certificate">
#       TV-MA
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="runtime">
#       57 min
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="genre">
#       Action, Adventure, Drama
#      </span>
#     </p>
#     <div class="ipl-rating-widget">
#      <div class="ipl-rating-star small">
#       <span class="ipl-rating-star__star">
#        <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#         <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#         </path>
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#        </svg>
#       </span>
#       <span class="ipl-rating-star__rating">
#        9.2
#       </span>
#      </div>
#      <div class="ipl-rating-interactive small ipl-rating-interactive--no-rating">
#       <input class="ipl-rating-interactive__state" data-reftag="ur_rt" data-tconst="tt0944947" id="checkbox-tt0944947" type="checkbox"/>
#       <label class="ipl-rating-interactive__star-container" for="checkbox-tt0944947">
#        <div class="ipl-rating-star ipl-rating-interactive__star">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#           <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          Rate
#         </span>
#        </div>
#       </label>
#       <div class="ipl-rating-selector" data-value="0" id="ipl-rating-selector-tt0944947">
#        <div class="ipl-rating-selector__selector ipl-rating-selector__wrapper">
#         <div class="ipl-rating-selector__reset">
#          <a href="#void">
#           <svg class="ipl-icon ipl-cancel-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M12 2C6.47 2 2 6.47 2 12s4.47 10 10 10 10-4.47 10-10S17.53 2 12 2zm5 13.59L15.59 17 12 13.41 8.41 17 7 15.59 10.59 12 7 8.41 8.41 7 12 10.59 15.59 7 17 8.41 13.41 12 17 15.59z">
#            </path>
#            <path d="M0 0h24v24H0z" fill="none">
#            </path>
#           </svg>
#          </a>
#         </div>
#         <span class="ipl-rating-selector__divider">
#         </span>
#         <form action="/ratings/_ajax/title" class="ipl-rating-selector__star-list" method="post">
#          <a class="ipl-rating-selector__star-link" data-value="1" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             1
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="2" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             2
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="3" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             3
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="4" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             4
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="5" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             5
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="6" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             6
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="7" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             7
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="8" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             8
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="9" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             9
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="10" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             10
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <fieldset class="ipl-rating-selector__fieldset">
#           <input name="tconst" type="hidden" value="tt0944947"/>
#           <input name="rating" type="text" value="0"/>
#           <input name="csrfToken" type="hidden" value=""/>
#           <input name="tracking_tag" type="hidden" value="ur_rt"/>
#           <input name="pageType" type="hidden" value="list"/>
#           <input name="subpageType" type="hidden" value="title"/>
#          </fieldset>
#          <noscript>
#           <input class="ipl-rating-selector__rating-submit" type="submit" value="Vote">
#           </input>
#          </noscript>
#         </form>
#         <span class="ipl-rating-selector__rating-value">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-selector__error ipl-rating-selector__wrapper">
#         <span>
#          Error: please try again.
#         </span>
#        </div>
#       </div>
#       <div class="ipl-rating-interactive__loader">
#        <img alt="loading" src="https://m.media-amazon.com/images/G/01/IMDb/spinning-progress.gif"/>
#       </div>
#      </div>
#     </div>
#     <p class="">
#      Nine noble families fight for control over the lands of Westeros, while an ancient enemy returns after being dormant for millennia.
#     </p>
#     <p class="text-muted text-small">
#      Stars:
#      <a href="/name/nm3592338/?ref_=ttls_li_st_0">
#       Emilia Clarke
#      </a>
#      ,
#      <a href="/name/nm0227759/?ref_=ttls_li_st_1">
#       Peter Dinklage
#      </a>
#      ,
#      <a href="/name/nm3229685/?ref_=ttls_li_st_2">
#       Kit Harington
#      </a>
#      ,
#      <a href="/name/nm0372176/?ref_=ttls_li_st_3">
#       Lena Headey
#      </a>
#     </p>
#     <p class="text-muted text-small">
#      <span class="text-muted">
#       Votes:
#      </span>
#      <span data-value="2157091" name="nv">
#       2,157,091
#      </span>
#     </p>
#     <div class="wtw-option-standalone" data-baseref="wl_li" data-tconst="tt0944947" data-watchtype="minibar">
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#   <div class="lister-item mode-detail">
#    <div class="lister-item-image ribbonize" data-tconst="tt8111088" style="position: relative;">
#     <a href="/title/tt8111088/?ref_=ttls_li_i">
#      <img alt="The Mandalorian" class="loadlate" data-tconst="tt8111088" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BN2M5YWFjN2YtYzU2YS00NzBlLTgwZWUtYWQzNWFhNDkyYjg3XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_UY209_CR0,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="140"/>
#     </a>
#     <div class="wl-ribbon poster touch retina not-inWL" title="Click to add to watchlist">
#     </div>
#    </div>
#    <div class="lister-item-content">
#     <h3 class="lister-item-header">
#      <span class="lister-item-index unbold text-primary">
#       3.
#      </span>
#      <a href="/title/tt8111088/?ref_=ttls_li_tt">
#       The Mandalorian
#      </a>
#      <span class="lister-item-year text-muted unbold">
#       (2019– )
#      </span>
#     </h3>
#     <p class="text-muted text-small">
#      <span class="certificate">
#       TV-14
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="runtime">
#       40 min
#      </span>
#      <span class="ghost">
#       |
#      </span>
#      <span class="genre">
#       Action, Adventure, Fantasy
#      </span>
#     </p>
#     <div class="ipl-rating-widget">
#      <div class="ipl-rating-star small">
#       <span class="ipl-rating-star__star">
#        <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#         <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#         </path>
#         <path d="M0 0h24v24H0z" fill="none">
#         </path>
#        </svg>
#       </span>
#       <span class="ipl-rating-star__rating">
#        8.7
#       </span>
#      </div>
#      <div class="ipl-rating-interactive small ipl-rating-interactive--no-rating">
#       <input class="ipl-rating-interactive__state" data-reftag="ur_rt" data-tconst="tt8111088" id="checkbox-tt8111088" type="checkbox"/>
#       <label class="ipl-rating-interactive__star-container" for="checkbox-tt8111088">
#        <div class="ipl-rating-star ipl-rating-interactive__star">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#           <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#         <span class="ipl-rating-star__star">
#          <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#         <span class="ipl-rating-star__rating">
#          Rate
#         </span>
#        </div>
#       </label>
#       <div class="ipl-rating-selector" data-value="0" id="ipl-rating-selector-tt8111088">
# ...
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="2" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             2
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="3" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             3
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="4" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             4
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="5" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             5
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="6" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             6
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="7" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             7
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="8" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             8
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="9" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             9
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <a class="ipl-rating-selector__star-link" data-value="10" href="#void">
#           <div class="ipl-rating-star ipl-rating-interactive__star">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#              <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             10
#            </span>
#           </div>
#           <div class="ipl-rating-star ipl-rating-interactive__star--empty">
#            <span class="ipl-rating-star__star">
#             <svg class="ipl-icon ipl-star-border-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22 9.24l-7.19-.62L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21 12 17.27 18.18 21l-1.63-7.03L22 9.24zM12 15.4l-3.76 2.27 1-4.28-3.32-2.88 4.38-.38L12 6.1l1.71 4.04 4.38.38-3.32 2.88 1 4.28L12 15.4z">
#              </path>
#              <path d="M0 0h24v24H0z" fill="none">
#              </path>
#             </svg>
#            </span>
#            <span class="ipl-rating-star__rating">
#             Rate
#            </span>
#           </div>
#          </a>
#          <fieldset class="ipl-rating-selector__fieldset">
#           <input name="tconst" type="hidden" value="tt2372162"/>
#           <input name="rating" type="text" value="0"/>
#           <input name="csrfToken" type="hidden" value=""/>
#           <input name="tracking_tag" type="hidden" value="ur_rt"/>
#           <input name="pageType" type="hidden" value="list"/>
#           <input name="subpageType" type="hidden" value="title"/>
#          </fieldset>
#          <noscript>
#           <input class="ipl-rating-selector__rating-submit" type="submit" value="Vote">
#           </input>
#          </noscript>
#         </form>
#         <span class="ipl-rating-selector__rating-value">
#          0
#         </span>
#        </div>
#        <div class="ipl-rating-selector__error ipl-rating-selector__wrapper">
#         <span>
#          Error: please try again.
#         </span>
#        </div>
#       </div>
#       <div class="ipl-rating-interactive__loader">
#        <img alt="loading" src="https://m.media-amazon.com/images/G/01/IMDb/spinning-progress.gif"/>
#       </div>
#      </div>
#     </div>
#     <p class="">
#      Convicted of a decade old crime of transporting drug money to an ex-girlfriend, normally law-abiding Piper Chapman is sentenced to a year and a half behind bars to face the reality of how life-changing prison can really be.
#     </p>
#     <p class="text-muted text-small">
#      Stars:
#      <a href="/name/nm2279940/?ref_=ttls_li_st_0">
#       Taylor Schilling
#      </a>
#      ,
#      <a href="/name/nm5335029/?ref_=ttls_li_st_1">
#       Danielle Brooks
#      </a>
#      ,
#      <a href="/name/nm0543383/?ref_=ttls_li_st_2">
#       Taryn Manning
#      </a>
#      ,
#      <a href="/name/nm1787501/?ref_=ttls_li_st_3">
#       Emma Myles
#      </a>
#     </p>
#     <p class="text-muted text-small">
#      <span class="text-muted">
#       Votes:
#      </span>
#      <span data-value="309099" name="nv">
#       309,099
#      </span>
#     </p>
#     <div class="wtw-option-standalone" data-baseref="wl_li" data-tconst="tt2372162" data-watchtype="minibar">
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#  </div>
#  <div class="row text-center lister-working hidden">
#  </div>
#  <div class="footer filmosearch">
#   <div class="desc">
#   </div>
#  </div>
# </div>

# %%
# get the list contating all shows details
title_list = title_elem.find_all('div',class_ = 'lister-item-content')
print(len(title_list))
# Out:
# 100

# %%
# create empty list
all_details_list = []

# %%
# loop to get all the details for all the shows 
for each in title_list:
    titles = each.h3.a['href']
    title_link = each.h3.a.get_text()
    rank = each.h3.find('span', class_ = 'lister-item-index unbold text-primary').get_text().replace('.', '')
    run_years = each.h3.find('span',class_ = 'lister-item-year text-muted unbold').get_text()
    p_tag = each.find_all('p',class_ = 'text-muted text-small')
    certificate = p_tag[0].find('span', class_= "certificate").get_text().replace('TV-','')
    runtime = p_tag[0].find('span', class_= "runtime").get_text().replace('min',' ')
    genre = p_tag[0].find('span', class_= "genre").get_text().strip()
    Rating = each.find('span', class_ = 'ipl-rating-star__rating').get_text()
    Actor = p_tag[1].find_all('a')
    Actors = [actor.get_text() for actor in Actor]
    Votes = p_tag[2].find_all('span')[1].get_text().replace(',','')
    Synopsis = each.find_all('p')[1].get_text().strip()
    dict_elements = {'Title' : titles,
                    'url' : title_link,
                    'Rank' : rank,
                    'Years of running' : run_years,
                    'Certificate' : certificate,
                    'Run time in minutes' : runtime,
                    'Genre' : genre,
                    'Rating' : Rating,
                    'Actors' : Actors,
                    'Votes' : Votes,
                    'Synopsis' : Synopsis}                        
    # Add the dictionary to the list
    all_details_list.append(dict_elements)

# %%
print(len(all_details_list))
# Out:
# 100

# %%
# create dataframe
import pandas as pd
Shows_df = pd.DataFrame(all_details_list)
Shows_df
# Out:
#                                 Title                          url Rank  \
# 0   /title/tt0903747/?ref_=ttls_li_tt                 Breaking Bad    1
# 1   /title/tt0944947/?ref_=ttls_li_tt              Game of Thrones    2
# 2   /title/tt8111088/?ref_=ttls_li_tt              The Mandalorian    3
# 3   /title/tt0108778/?ref_=ttls_li_tt                      Friends    4
# 4   /title/tt0141842/?ref_=ttls_li_tt                 The Sopranos    5
# ..                                ...                          ...  ...
# 95  /title/tt2357547/?ref_=ttls_li_tt                Jessica Jones   96
# 96  /title/tt0098800/?ref_=ttls_li_tt  The Fresh Prince of Bel-Air   97
# 97  /title/tt0285333/?ref_=ttls_li_tt                        Alias   98
# 98  /title/tt0096708/?ref_=ttls_li_tt         Tales from the Crypt   99
# 99  /title/tt2372162/?ref_=ttls_li_tt      Orange Is the New Black  100
#
#    Years of running Certificate Run time in minutes  \
# 0       (2008–2013)          MA                49
# 1       (2011–2019)          MA                57
# 2          (2019– )          14                40
# 3       (1994–2004)          14                22
# 4       (1999–2007)          MA                55
# ..              ...         ...                 ...
# 95      (2015–2019)          MA                56
# 96      (1990–1996)          PG                22
# 97      (2001–2006)          14                42
# 98      (1989–1996)          MA                25
# 99      (2013–2019)          MA                59
#
#                          Genre Rating  \
# 0       Crime, Drama, Thriller    9.5
# 1     Action, Adventure, Drama    9.2
# 2   Action, Adventure, Fantasy    8.7
# 3              Comedy, Romance    8.9
# 4                 Crime, Drama    9.2
# ..                         ...    ...
# 95        Action, Crime, Drama    7.9
# 96                      Comedy    7.9
# 97      Action, Drama, Mystery    7.6
# 98      Comedy, Crime, Fantasy      8
# 99        Comedy, Crime, Drama    8.1
#
#                                                Actors    Votes  \
# 0   [Bryan Cranston, Aaron Paul, Anna Gunn, Betsy ...  1968905
# 1   [Emilia Clarke, Peter Dinklage, Kit Harington,...  2157091
# 2   [Pedro Pascal, Chris Bartlett, Katee Sackhoff,...   540449
# 3   [Jennifer Aniston, Courteney Cox, Lisa Kudrow,...  1023478
# 4   [James Gandolfini, Lorraine Bracco, Edie Falco...   421125
# ..                                                ...      ...
# 95  [Krysten Ritter, Rachael Taylor, Eka Darville,...   219041
# 96  [Will Smith, James Avery, Alfonso Ribeiro, Tat...   138906
# 97  [Jennifer Garner, Ron Rifkin, Carl Lumbly, Kev...    52402
# 98  [John Kassir, Miguel Ferrer, Cam Clarke, Larry...    25552
# 99  [Taylor Schilling, Danielle Brooks, Taryn Mann...   309099
#
#                                              Synopsis
# 0   A chemistry teacher diagnosed with inoperable ...
# 1   Nine noble families fight for control over the...
# 2   The travels of a lone bounty hunter in the out...
# 3   Follows the personal and professional lives of...
# 4   New Jersey mob boss Tony Soprano deals with pe...
# ..                                                ...
# 95  Following the tragic end of her brief superher...
# 96  A streetwise, poor young man from Philadelphia...
# 97  Sydney Bristow is an international spy recruit...
# 98  Tales of horror based on the gruesome E.C. com...
# 99  Convicted of a decade old crime of transportin...
#
# [100 rows x 11 columns]

# %%
#saving data
import os  
os.makedirs('ETL_practice/Resources', exist_ok=True)  
IMDB_df = Shows_df.to_csv('ETL_practice/Resources/Top 100 TV Series.csv')

# %%
browser.quit()
